# %%
import pandas as pd

# %%
df = pd.read_excel("../Desktop/Data_Cleaning_Pandas/Customer Call List.xlsx")

# %%
#remove duplicate rows
df = df.drop_duplicates()
#remove unnecessary columns
df = df.drop(columns="Not_Useful_Column")

# %%
#clean Last_Name column
# df["Last_Name"] = df["Last_Name"].str.lstrip("...").str.lstrip("/").str.rstrip("_")
df["Last_Name"] = df["Last_Name"].str.strip("123./_")

# %%
#clean Phone_Number column
df["Phone_Number"] = df["Phone_Number"].str.replace("[^a-zA-Z0-9]","",regex=True)
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x)[0:3] + "-" + str(x)[3:6] + "-" + str(x)[6:10])
df["Phone_Number"] = df["Phone_Number"].str.replace(r"nan--|Na--","",regex=True)

# %%
#clean Street_Address column
df[["Street_Address", "State", "Zip_Code"]] = df["Address"].str.split(",",n=2,expand=True)

# %%
#clean Paying Customer	Do_Not_Contact column
df["Paying Customer"] = df["Paying Customer"].str.replace("Yes", "Y").str.replace("No","N")
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("Yes", "Y").str.replace("No","N")

# %%
#remove null value
df = df.fillna("")
df = df.replace("N/a","")

# %%
#Give a list of customers to call
for x in df.index:
    if df.loc[x,"Do_Not_Contact"] == "Y":
        df.drop(x,inplace=True)
for x in df.index:
    if df.loc[x,"Phone_Number"] == "":
        df.drop(x,inplace=True)
df = df.reset_index(drop=True).drop(columns=["Address","Zip_Code"])
df
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0        1001      Frodo     Baggins  123-545-5421               Y
# 1        1005        Jon        Snow  876-678-3469               Y
# 2        1008   Sherlock      Holmes  876-678-3469               N
# 3        1010      Peter      Parker  123-545-5421               Y
# 4        1013        Don      Draper  123-543-2345               Y
# 5        1014     Leslie       Knope  876-678-3469               Y
# 6        1015       Toby  Flenderson  304-762-2467               N
# 7        1016        Ron     Weasley  123-545-5421               N
# 8        1017   Michael        Scott  123-643-9775               Y
# 9        1020     Anakin   Skywalker  876-678-3469               Y
#
#   Do_Not_Contact        Street_Address          State
# 0              N        123 Shire Lane          Shire
# 1              N      123 Dragons Road
# 2              N         98 Clue Drive
# ...
